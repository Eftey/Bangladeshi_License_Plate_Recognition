# %% [markdown]
# <a href="https://colab.research.google.com/github/Eftey/Bangladeshi_License_Plate_Recognition/blob/Master/LPR_Runtime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Eftey/Bangladeshi_License_Plate_Recognition
# Out:
# Cloning into 'Bangladeshi_License_Plate_Recognition'...
# remote: Enumerating objects: 753, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 753 (delta 8), reused 19 (delta 7), pack-reused 733
# Receiving objects: 100% (753/753), 22.53 MiB | 9.83 MiB/s, done.
# Resolving deltas: 100% (278/278), done.

# %%
# !pip install wandb --upgrade
# Out:
# ...
#      |████████████████████████████████| 1.8 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 181 kB 47.6 MB/s
# ...
#      |████████████████████████████████| 144 kB 45.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=b31182698672b66de318e58ef2d27ed3cf13210bb32419962f0f6c59aa3725ec
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...

# %%
import wandb

# %%
import wandb
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
config = dict(
    epochs=5,
    classes=10,
    kernels=[16, 32],
    batch_size=128,
    learning_rate=0.005,
    dataset="MNIST",
    architecture="CNN")

# %%
# !python /content/Bangladeshi_License_Plate_Recognition/main.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# True
# wandb: Currently logged in as: eftey. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.16
# wandb: Run data is saved locally in /content/wandb/run-20220509_130505-2oxehtm8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dulcet-leaf-9
# wandb: ⭐️ View project at https://wandb.ai/eftey/pytorch-demo
# wandb: 🚀 View run at https://wandb.ai/eftey/pytorch-demo/runs/2oxehtm8
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# ...
