# %% [markdown]
# <a href="https://colab.research.google.com/github/Eftey/Bangladeshi_License_Plate_Recognition/blob/Master/Data_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kelvinliu04/lpr_pytorch.git
# Out:
# Cloning into 'lpr_pytorch'...
# remote: Enumerating objects: 501, done.
# remote: Counting objects: 100% (501/501), done.
# remote: Compressing objects: 100% (269/269), done.
# remote: Total 501 (delta 235), reused 497 (delta 231), pack-reused 0
# Receiving objects: 100% (501/501), 19.73 MiB | 27.60 MiB/s, done.
# Resolving deltas: 100% (235/235), done.

# %%
# !python /content/lpr_pytorch/main.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# True
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100% 160M/160M [00:01<00:00, 145MB/s]
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
